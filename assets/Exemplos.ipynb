# %% [markdown]
# # Exemplos de cõdigos

# %% [markdown]
# ## Naive Bayes
# ### Gerar matrix de confusão com plotly

# %%
import plotly.figure_factory as ff

conf_matrix = confusion_matrix(y_train, y_pred_train)

# Definindo  nomes de classes
class_names = ['Average', 'High', 'Low']

# Plotando a matriz de confusão com Plotly
fig = ff.create_annotated_heatmap(
    z=conf_matrix,
    x=class_names,
    y=class_names,
    colorscale='Blues',
    showscale=True
)
fig.update_layout(
    title='Matriz de Confusão',
    xaxis_title='Predicted labels',
    yaxis_title='True labels',
    font=dict(
        family='Arial',
        size=12,
        color='black'
    )
)

# %% [markdown]
# ### Gerar matriz de confusão com import matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# criando função para matriz de confusão
def plot_confusion_matrix(y_true, y_pred, labels= None, title='Matriz de Confusão'):
    
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    labels = ['Average', 'High', 'Low']
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.title(title)
    plt.ylabel('Classe Real')
    plt.xlabel('Classe Predita')
    plt.tight_layout()
    plt.show()
