# %%
# Importanto bibliotecas necessárias
import pandas as pd
from ydata_profiling import ProfileReport

# Carregando o dataset
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv", delimiter=',')

# Criando uma variável para armazenar o relatório
profile = ProfileReport(df, title="Profiling Report")

# %%
# Mostrando as primeiras linahs do dataset
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Gerando o relatório em HTML
profile.to_file("WA_Fn-UseC_-HR-Employee-Attrition_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 28.27it/s]
