# %% [markdown]
# ### Boas práticas

# %% [markdown]
# ### Compreensão dos Fundamentos Matemáticos
# Antes de aplicar a regressão linear, é crucial entender os fundamentos matemáticos por trás da técnica. Isso inclui a equação da reta (Y = mX + b) e como ela modela a relação entre variáveis. Essa compreensão ajuda a interpretar os resultados e ajustar o modelo adequadamente.
#
# ### Validação de Modelos com Dados Históricos
# Sempre valide seus modelos de regressão linear com dados históricos antes de aplicá-los em cenários reais. Isso garante que o modelo seja preciso e confiável, evitando previsões incorretas que podem impactar decisões importantes.
#
# ### Exploração de Diferentes Bibliotecas
# Familiarize-se com várias bibliotecas de Python para implementar modelos de regressão. Isso não só aumenta sua flexibilidade como profissional, mas também é uma habilidade frequentemente exigida no mercado de trabalho.
#
# ### Documentação e Justificação do Processo
# Documente cada etapa do processo de construção do modelo, desde o pré-processamento de dados até a avaliação do modelo. Justifique suas escolhas e métodos, pois isso demonstra um entendimento profundo e profissionalismo, além de ser útil para revisões futuras.
#
# ### Exemplo de utilização no mercado de trabalho:
#  - **Previsão de Vendas**: Empresas de e-commerce utilizam regressão linear para prever vendas futuras com base em dados de publicidade e promoções passadas, ajudando a otimizar campanhas de marketing.
#  - **Avaliação de Preços de Imóveis**: Agências imobiliárias aplicam regressão linear múltipla para estimar o valor de propriedades considerando múltiplas variáveis, como localização, tamanho e características adicionais.

# %% [markdown]
# ## Exemplo de código executável (em Python) que ilustra a regressão linear simples:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Dados de exemplo
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 3, 5, 7, 11])

# Criar o modelo de regressão linear
model = LinearRegression()

# Ajustar o modelo aos dados
model.fit(X, y)

# Fazer previsões
y_pred = model.predict(X)

# Visualizar os resultados
plt.scatter(X, y, color='blue', label='Dados reais')
plt.plot(X, y_pred, color='red', label='Linha de regressão')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# - `import numpy as np`: Importa a biblioteca NumPy para manipulação de arrays.
# - `import matplotlib.pyplot as plt`: Importa a biblioteca Matplotlib para visualização de dados.
# - `from sklearn.linear_model import LinearRegression`: Importa a classe LinearRegression da biblioteca scikit-learn para criar o modelo de regressão.
# - `X e y`: Define os dados de entrada e saída, respectivamente.
# - `model = LinearRegression()`: Cria uma instância do modelo de regressão linear.
# - `model.fit(X, y)`: Ajusta o modelo aos dados fornecidos.
# - `y_pred` = model.predict(X): Faz previsões com base no modelo ajustado.
# - `plt.scatter e plt.plot`: Visualiza os dados reais e a linha de regressão.
