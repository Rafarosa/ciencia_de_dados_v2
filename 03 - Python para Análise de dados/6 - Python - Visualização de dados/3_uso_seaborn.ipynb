# %% [markdown]
# # Uso de Seaborn
#
# Na aula anterior, você compreendeu o uso da biblioteca Matplotlib. Nesta aula, você vai:
# - Comparar os recursos das bibliotecas Matplotlib e Seaborn;
#
# - Aplicar gráficos utilizando a biblioteca Seaborn, para identificar padrões, tendências, outliers e a distribuição de variáveis;
#
# - Analisar a correlação entre múltiplas variáveis em um conjunto de dados.
#
# Mas dados sobre a biblioteca - https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
# importando bibliotecas e lendo o arquivo csv

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv('clientes-v3-preparado.csv')
df.head(10)
# Out:
#    idade        data               estado   salario      nivel_educacao  \
# 0     56  1968-01-19                 Pará  13550.54        Ensino Médio
# 1     49  1975-01-31  Rio Grande do Norte   3124.72        Ensino Médio
# 2     54  1969-08-26         Minas Gerais   7534.60        Ensino Médio
# 3     61  1963-03-19                Amapá   4067.73  Ensino Fundamental
# 4     30  1993-12-09              Alagoas   6809.94        Ensino Médio
# 5     54  1969-06-24                 Pará   9025.74        Ensino Médio
# 6     28  1996-03-25            Tocantins   9493.67     Ensino Superior
# 7     30  1993-06-20            Tocantins   4072.60        Ensino Médio
# 8     24  2000-02-21  Rio Grande do Norte   4039.96  Ensino Fundamental
# 9     35  1988-08-02             Amazonas   3457.97  Ensino Fundamental
#
#    numero_filhos estado_civil area_atuacao  anos_experiencia  \
# 0              0       Casado   Tecnologia                17
# ...

# %%
# Gráfico de Dispersão
sns.jointplot(x='idade', y='salario', data=df, kind='scatter') 
plt.show()

# %%
# Gráfico de Densidade
plt.figure(figsize=(10, 6))
sns.kdeplot(df['salario'], fill=True, color='#863e9c')
plt.title('Densidade de Salários')
plt.xlabel('Salário')
plt.show()

# %%
# Gráfico de Pairplot - Dispersão e Histograma
sns.pairplot(df[['idade', 'salario', 'anos_experiencia', 'nivel_educacao']])
plt.show()

# %%
# Gráfico de Regressão
sns.regplot(x='idade', y='salario', data=df, color='#278f65', scatter_kws={'alpha': 0.5, 'color': '#34c289'})
plt.title('Regressão de Salário por Idade')
plt.xlabel('Idade')
plt.ylabel('Salário')
plt.show()

# %%
# Gráfico countplot com hue
sns.countplot(x='estado_civil', hue='nivel_educacao', data=df, palette='pastel')
plt.xlabel('Estado Civil')
plt.ylabel('Quantidade Clientes')
plt.legend(title='Nível de Educação')
plt.show()
